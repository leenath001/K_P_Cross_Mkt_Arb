# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))  

from src import helpers

x = helpers.pinnacle_odds('basketball_nba', 3)
print(x)
# Out:
# Requests used: 4 / 496 remaining
#                 home                 away             commence              outcome  decimal_odds  fair_prob  vig_pct
# Los Angeles Clippers New Orleans Pelicans 2026-03-02T02:10:00Z Los Angeles Clippers          1.32     0.7349    3.080
# Los Angeles Clippers New Orleans Pelicans 2026-03-02T02:10:00Z New Orleans Pelicans          3.66     0.2651    3.080
#   Los Angeles Lakers     Sacramento Kings 2026-03-02T02:40:00Z   Los Angeles Lakers          1.15     0.8448    2.931
#   Los Angeles Lakers     Sacramento Kings 2026-03-02T02:40:00Z     Sacramento Kings          6.26     0.1552    2.931
