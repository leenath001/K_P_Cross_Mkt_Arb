# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))  
from theODDS import p_helpers as h
import config

# %%
sports = config.SPORTS

sports
# Out:
# ['basketball_ncaab',
#  'soccer_mexico_ligamx',
#  'soccer_argentina_primera_division',
#  'soccer_brazil_campeonato']

# %% [markdown]
# # Testing Pinnacle Odds Fn

# %%
x = h.pinnacle_odds(sports, hrs = 5, live = False)
display(x)
# Out:
# Requests used: 22 / 478 remaining
# No events for: basketball_ncaab
#
# Requests used: 22 / 478 remaining
# No events for: soccer_mexico_ligamx
#
# Requests used: 22 / 478 remaining
# No events for: soccer_argentina_primera_division
#
# Requests used: 22 / 478 remaining
# No events for: soccer_brazil_campeonato
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x = h.pinnacle_odds(sports, hrs = 5, live = False)
#       2 display(x)
#
# File ~/Desktop/Projects/K_P_Cross_Mkt_Arb/theODDS/p_helpers.py:72, in pinnacle_odds(sports, hrs, live)
#      69 df = pd.DataFrame(rows)
#      71 if df.empty or df[df['bookmaker'] == 'pinnacle'].empty:
# ---> 72     raise ValueError("No events found. Pinnacle odds may not be live.")
# ...
