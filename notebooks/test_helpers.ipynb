# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))  
from theODDS import p_helpers as p
from KALSHI import k_helpers as k 
import config

# %% [markdown]
# # Testing functions:
#
# Make a PoC file - no threading, run as simple as possible to show this is possible.

# %%
# sports = config.SPORTS

sports = ["basketball_nba"]

# %% [markdown]
# ## Pinnacle Odds Fn

# %%
x = p.pinnacle_odds(sports, hrs = 70, live = False)
display(x)
# Out:
#             sport                          event_id               home  \
# 0  basketball_nba  dce0f3f389617fa7daa990c209ee8acc      Atlanta Hawks
# 1  basketball_nba  dce0f3f389617fa7daa990c209ee8acc      Atlanta Hawks
# 2  basketball_nba  ec27c42246b5e40c34f4c2d93930ed20      Orlando Magic
# 3  basketball_nba  ec27c42246b5e40c34f4c2d93930ed20      Orlando Magic
# 4  basketball_nba  c2ff7eb921314ca5ebc2ad18db189374  Memphis Grizzlies
# 5  basketball_nba  c2ff7eb921314ca5ebc2ad18db189374  Memphis Grizzlies
# 6  basketball_nba  14dede373d304abbddc590d2bcc81e4e  San Antonio Spurs
# 7  basketball_nba  14dede373d304abbddc590d2bcc81e4e  San Antonio Spurs
# 8  basketball_nba  76e52ccb4140e4936de62dbadae0808d     Denver Nuggets
# 9  basketball_nba  76e52ccb4140e4936de62dbadae0808d     Denver Nuggets
#
#                      away                  commence bookmaker  \
# 0         New York Knicks 2026-04-06 19:10:00-04:00  pinnacle
# ...

# %% [markdown]
# ## Kalshi Fn's

# %%
x2 = k.kalshi_odds(x)
display(x2)
# display(x2[x2['signal'] == True])
# Out:
#             sport                          event_id               home  \
# 0  basketball_nba  14dede373d304abbddc590d2bcc81e4e  San Antonio Spurs
# 1  basketball_nba  14dede373d304abbddc590d2bcc81e4e  San Antonio Spurs
# 2  basketball_nba  76e52ccb4140e4936de62dbadae0808d     Denver Nuggets
# 3  basketball_nba  c2ff7eb921314ca5ebc2ad18db189374  Memphis Grizzlies
# 4  basketball_nba  dce0f3f389617fa7daa990c209ee8acc      Atlanta Hawks
# 5  basketball_nba  dce0f3f389617fa7daa990c209ee8acc      Atlanta Hawks
# 6  basketball_nba  ec27c42246b5e40c34f4c2d93930ed20      Orlando Magic
# 7  basketball_nba  ec27c42246b5e40c34f4c2d93930ed20      Orlando Magic
#
#                      away                  commence              outcome  \
# 0      Philadelphia 76ers 2026-04-06 20:10:00-04:00   Philadelphia 76ers
# 1      Philadelphia 76ers 2026-04-06 20:10:00-04:00    San Antonio Spurs
# 2  Portland Trail Blazers 2026-04-06 21:10:00-04:00       Denver Nuggets
# ...
