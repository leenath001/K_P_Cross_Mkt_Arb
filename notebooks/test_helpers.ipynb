# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))  
from theODDS import p_helpers as p
from KALSHI import k_helpers as k 
import config

# %%
sports = config.SPORTS

sports
# Out:
# ['soccer_argentina_primera_division', 'soccer_brazil_campeonato']

# %% [markdown]
# # Testing Pinnacle Odds Fn

# %%
x = p.pinnacle_odds(sports, hrs = 24, live = False)
display(x)
# Out:
# Requests used: 51 / 449 remaining
#
# Requests used: 52 / 448 remaining
#                                 sport                          event_id  \
# 0   soccer_argentina_primera_division  66de5d9cc965e367e81aeab708b20f27
# 1   soccer_argentina_primera_division  66de5d9cc965e367e81aeab708b20f27
# 2   soccer_argentina_primera_division  66de5d9cc965e367e81aeab708b20f27
# 3   soccer_argentina_primera_division  903ad5bd703fca467c9b30bbccc8c20f
# 4   soccer_argentina_primera_division  903ad5bd703fca467c9b30bbccc8c20f
# 5   soccer_argentina_primera_division  903ad5bd703fca467c9b30bbccc8c20f
# 6   soccer_argentina_primera_division  84b95bba1b9b8c6a7fe02a908af5b823
# 7   soccer_argentina_primera_division  84b95bba1b9b8c6a7fe02a908af5b823
# 8   soccer_argentina_primera_division  84b95bba1b9b8c6a7fe02a908af5b823
# 9   soccer_argentina_primera_division  0c13546fa0466959ba505d7cde3911f9
# 10  soccer_argentina_primera_division  0c13546fa0466959ba505d7cde3911f9
# ...

# %%
x2 = k.kalshi_odds(x)
display(x2)
# Out:
# {'KXARGPREMDIVGAME', 'KXBRASILEIROGAME'}
