# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))  

from src import helpers as h

# %%
x = h.pinnacle_odds('basketball_ncaab', 6)
print(x)
# Out:
# Requests used: 7 / 493 remaining
#                          home                          away             commence                       outcome  decimal_odds  fair_prob  vig_pct
#               Morgan St Bears           Norfolk St Spartans 2026-03-02T23:00:00Z               Morgan St Bears          2.45     0.3890    4.919
#               Morgan St Bears           Norfolk St Spartans 2026-03-02T23:00:00Z           Norfolk St Spartans          1.56     0.6110    4.919
#          Cleveland St Vikings                 IUPUI Jaguars 2026-03-03T00:00:00Z          Cleveland St Vikings          1.76     0.5464    3.988
#          Cleveland St Vikings                 IUPUI Jaguars 2026-03-03T00:00:00Z                 IUPUI Jaguars          2.12     0.4536    3.988
#           Delaware St Hornets    South Carolina St Bulldogs 2026-03-03T00:00:00Z           Delaware St Hornets          1.74     0.5492    4.641
# ...
